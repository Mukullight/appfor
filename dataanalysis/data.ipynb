# %%
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
data = pd.read_csv('dataanalysis/DinerDataTest - Sheet1.csv')

# %%
data
# Out:
#    First Name  Last Name Seniority         City                 State  \
# 0     Lynette       Carl  Director       Durham        North Carolina
# 1    Flemming      Jones        Vp  Los Angeles            California
# 2     Jenifer       Howe  Director      Phoenix               Arizona
# 3    Margaret      Renzi  Director  New Orleans             Louisiana
# 4       Lauri      Biggs  Director       Boston         Massachusetts
# ..        ...        ...       ...          ...                   ...
# 94    Melissa   Barreira  Director      Bedford         New Hampshire
# 95    Michael   Thompson   Partner    Tipp City                  Ohio
# 96     Nicole      Lytle  Director      Bedford         New Hampshire
# 97      Kevin  Weishaupt   C suite   Washington  District of Columbia
# 98      Bobby      Adams   Partner  Gainesville              Virginia
#
#                                               Address  \
# 0   1 Seaport Lane, Boston, Massachusetts, United ...
# ...

# %%
import kagglehub
import pandas as pd
import os

# Download latest version of the dataset
path = kagglehub.dataset_download("mohdshahnawazaadil/restaurant-dataset")

# Print the path to the dataset directory
print("Path to dataset files:", path)

# List files in the dataset directory to find the CSV file
for file in os.listdir(path):
    print(file)
    if file.endswith('.csv'):
        csv_path = os.path.join(path, file)
        print(f"Found CSV file: {csv_path}")
        # Read the CSV file
        df = pd.read_csv(csv_path)
        print(df.head())  # Display the first few rows of the DataFrame
# Out:
# Path to dataset files: /home/mukullight/.cache/kagglehub/datasets/mohdshahnawazaadil/restaurant-dataset/versions/1
# Dataset .csv
# Found CSV file: /home/mukullight/.cache/kagglehub/datasets/mohdshahnawazaadil/restaurant-dataset/versions/1/Dataset .csv
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Country Code'].value_counts()
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
import plotly.express as px

# Select relevant columns and drop rows with missing values
df_plot = df[['Latitude', 'Longitude', 'Country Code', 'Restaurant Name']].dropna()

# Create an interactive scatter map
fig = px.scatter_geo(df_plot,
                     lat='Latitude',
                     lon='Longitude',
                     color='Country Code',  # Color points by Country Code
                     hover_name='Restaurant Name',  # Show restaurant name on hover
                     hover_data={'Country Code': True, 'Latitude': True, 'Longitude': True},
                     projection='natural earth',  # Use natural earth projection for the map
                     title='Restaurant Locations by Country Code',
                     color_discrete_sequence=px.colors.qualitative.Bold)  # Distinct colors

# Customize the layout with size adjustments
fig.update_layout(
    geo=dict(showframe=False, showcoastlines=True, projection_type='natural earth'),
    legend_title_text='Country Code',
    title_x=0.8,  # Title position as provided
    width=1000,  # Set plot width in pixels
    height=500  # Set plot height in pixels
)

# Display the plot in the Jupyter cell
fig.show()
